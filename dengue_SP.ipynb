# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Truncation doesn't work directly
#
# Database seems to use the most updated version of all data for any query, no possibility to access specific "version" with data from specific date of digitalization.

# %%
# 3550308 = SP city geocode
url = 'https://info.dengue.mat.br/api/alertcity'
search_filter = (
    'geocode=1200013&' + 
    'disease=dengue&format=csv&' +
    'ew_start=1&ew_end=52&' +
    'ey_start=2013&ey_end=2013'
)
df = pd.read_csv('%s?%s' % (url, search_filter))
print(url)
df.head(10)
# Out:
# https://info.dengue.mat.br/api/alertcity
#    data_iniSE      SE  casos_est  casos_est_min  casos_est_max  casos  \
# 0  2013-12-22  201352        0.0              0              0      0
# 1  2013-12-15  201351        2.0              2              2      2
# 2  2013-12-08  201350        2.0              2              2      2
# 3  2013-12-01  201349        1.0              1              1      1
# 4  2013-11-24  201348        1.0              1              1      1
# 5  2013-11-17  201347        0.0              0              0      0
# 6  2013-11-10  201346        0.0              0              0      0
# 7  2013-11-03  201345        1.0              1              1      1
# 8  2013-10-27  201344        2.0              2              2      2
# 9  2013-10-20  201343        0.0              0              0      0
#
#       p_rt1  p_inc100k  Localidade_id  nivel  ...    umidmed    umidmin  \
# 0  0.000000   0.000000              0      1  ...  80.207059  47.142857
# ...

# %%
df.columns
# Out:
# Index(['data_iniSE', 'SE', 'casos_est', 'casos_est_min', 'casos_est_max',
#        'casos', 'p_rt1', 'p_inc100k', 'Localidade_id', 'nivel', 'id',
#        'versao_modelo', 'tweet', 'Rt', 'pop', 'tempmin', 'umidmax',
#        'receptivo', 'transmissao', 'nivel_inc', 'umidmed', 'umidmin',
#        'tempmed', 'tempmax', 'casprov', 'casprov_est', 'casprov_est_min',
#        'casprov_est_max', 'casconf', 'notif_accum_year'],
#       dtype='object')

# %%
from pysus.online_data import SINAN
sinan = SINAN().load()
